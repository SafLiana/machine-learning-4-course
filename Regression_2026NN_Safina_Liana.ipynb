# %% [markdown]
# ### Подключение модулей

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Целью этого проекта является прогнозирование и анализ цен продажи жилья в США. Требуется построить регрессионную модель для прогнозирования цен на жилье в США на основе различных факторов.

# %% [markdown]
# ### Загрузка данных

# %%
df = pd.read_csv('USA_Housing (3).csv')

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %% [markdown]
# Данные содержат следующие столбцы:
# - __Avg. Area Income__ (Сред. Доход от района): Средний доход жителей города по региону.
# - __Avg. Area House Age__ (Сред. Площадь дома): Средний возраст домов в районе.
# - __Avg. Area Number of Rooms__ (Сред. Площадь Количество комнат): Среднее количество комнат в домах в том же городе.
# - __Avg. Area Number of Bedrooms__ (Сред. Площадь Количество спален): Среднее количество спален в домах в том же городе.
# - __Area Population__ (Население региона): Население городского дома, в котором находится.
# - __Price__ (Цена): Цена, по которой был продан дом.
# - __Address__ (Адрес): Адрес дома.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# min                        2.000000       172.610686  1.593866e+04
# 25%                        3.140000     29403.928702  9.975771e+05
# 50%                        4.050000     36199.406689  1.232669e+06
# 75%                        4.490000     42861.290769  1.471210e+06
# max                        6.500000     69621.713378  2.469066e+06

# %%
pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count         5000.0000            5000.0000                  5000.0000
# mean         68583.1090               5.9772                     6.9878
# std          10657.9912               0.9915                     1.0058
# min          17796.6312               2.6443                     3.2362
# 25%          61480.5624               5.3223                     6.2993
# 50%          68804.2864               5.9704                     7.0029
# 75%          75783.3387               6.6508                     7.6659
# max         107701.7484               9.5191                    10.7596
#
#        Avg. Area Number of Bedrooms  Area Population        Price
# count                     5000.0000        5000.0000    5000.0000
# mean                         3.9813       36163.5160 1232072.6541
# std                          1.2341        9925.6501  353117.6266
# min                          2.0000         172.6107   15938.6579
# 25%                          3.1400       29403.9287  997577.1350
# 50%                          4.0500       36199.4067 1232669.3780
# 75%                          4.4900       42861.2908 1471210.2042
# max                          6.5000       69621.7134 2469065.5942

# %%
df.hist(figsize=(20,20));
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.pairplot(df)
plt.show()

# %%
sns.distplot(df['Price'])
plt.show()

# %%
sns.regplot(y='Price', x='Avg. Area Income', data=df)
plt.show()

# %%
df[['Avg. Area Income', 'Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population', 'Price']].corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                        1.0000              -0.0020
# Avg. Area House Age                    -0.0020               1.0000
# Avg. Area Number of Rooms              -0.0110              -0.0094
# Avg. Area Number of Bedrooms            0.0198               0.0061
# Area Population                        -0.0162              -0.0187
# Price                                   0.6397               0.4525
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                                -0.0110
# Avg. Area House Age                             -0.0094
# Avg. Area Number of Rooms                        1.0000
# Avg. Area Number of Bedrooms                     0.4627
# Area Population                                  0.0020
# Price                                            0.3357
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# Avg. Area Income                                    0.0198          -0.0162
# Avg. Area House Age                                 0.0061          -0.0187
# Avg. Area Number of Rooms                           0.4627           0.0020
# Avg. Area Number of Bedrooms                        1.0000          -0.0222
# Area Population                                    -0.0222           1.0000
# Price                                               0.1711           0.4086
#
#                               Price
# Avg. Area Income             0.6397
# Avg. Area House Age          0.4525
# Avg. Area Number of Rooms    0.3357
# Avg. Area Number of Bedrooms 0.1711
# Area Population              0.4086
# Price                        1.0000

# %%
sns.heatmap(df[['Avg. Area Income', 'Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population', 'Price']].corr(), annot=True)
plt.show()

# %%
df['House Age'] = df['Avg. Area House Age'].apply(int)

# %%
plt.figure(figsize = (12, 6), dpi = 200)
sns.barplot(x = 'House Age', y = 'Price', data = df, ci = None)
plt.show()

# %%
df['Number of Rooms'] = df['Avg. Area Number of Rooms'].apply(int)

# %%
plt.figure(figsize = (12, 6), dpi = 200)
sns.barplot(x = 'Number of Rooms', y = 'Price', data = df, ci = None)
plt.show()

# %%
df['Number of Bedrooms'] = df['Avg. Area Number of Bedrooms'].apply(int)

# %%
plt.figure(figsize = (12, 6), dpi = 200)
sns.barplot(x = 'Number of Bedrooms', y = 'Price', data = df, ci = None)
plt.show()

# %% [markdown]
# ### Обучение модели линейной регрессии

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address',
#        'House Age', 'Number of Rooms', 'Number of Bedrooms'],
#       dtype='object')

# %%
X = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]

# %%
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Линейная регрессия

# %%
from sklearn.linear_model import LinearRegression

# %%
lrm = LinearRegression()
lrm.fit(X_train, y_train)
predictions_lr = lrm.predict(X_test)

# %%
lrm.intercept_
# Out:
# np.float64(-2638673.4261916303)

# %%
lrm.coef_
# Out:
# array([2.16257989e+01, 1.65590393e+05, 1.19827783e+05, 2.36109526e+03,
#        1.52165814e+01])

# %%
predictions = lrm.predict(X_test)

# %%
predictions
# Out:
# array([1308536.13592627, 1237122.72746484, 1243835.62817059, ...,
#        1457119.79297249, 1483428.95309395, 1047510.59737165])

# %%
y_test.round(3)
# Out:
# 1501   1339096.0770
# 2586   1251794.1790
# 2653   1340094.9660
# 1055   1431507.6230
# 705    1042373.5240
#            ...
# 3563   1348221.7650
# 1538   1309937.3990
# 1837   1472887.2470
# 2380   1409762.1190
# 1912   1009606.2840
# Name: Price, Length: 1500, dtype: float64

# %%
plt.scatter(y_test, predictions)
plt.show()

# %%
sns.regplot(x=y_test,y=predictions,line_kws={"color":"black"})
plt.show()

# %%
sns.distplot((y_test - predictions))
plt.show()

# %% [markdown]
# ### Метрики оценки качества регрессии
#
#
# Общие показатели оценки для задач регрессии:
#
# **Mean Absolute Error** (MAE Средняя абсолютная ошибка) - это среднее значение абсолютного значения ошибок:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE Среднеквадратическая ошибка) - это среднее значение квадратов ошибок:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE Среднеквадратическая ошибка) - это квадратный корень из среднего квадрата ошибок:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# **Коэффициент детерминации** $R^{2}$
#
# $$R^2 = 1 - \frac{\frac{1}{n}\sum^{n}_{i}{(y - y_{pred})^2}}{\frac{1}{n}\sum^{n}_{i}{(y - \bar{y})^2}}$$

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 81135.56609336873

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 10068422551.401155

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# np.float64(100341.52954485573)

# %%
metrics.r2_score(y_test, predictions)
# Out:
# 0.9146818498753992

# %% [markdown]
# ## Обучение модели нейронной сети

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

numeric_features = [
    'Avg. Area Income',
    'Avg. Area House Age',
    'Avg. Area Number of Rooms',
    'Avg. Area Number of Bedrooms',
    'Area Population']
X = df[numeric_features]
y = df['Price']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(5,)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mean_squared_error',
    metrics=['mean_absolute_error'])

# %%
history = model.fit(
    X_train_scaled, y_train,
    epochs=200,
    batch_size=32,
    validation_data=(X_test_scaled, y_test),
    verbose=1)
# Out:
# Epoch 1/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1635779215360.0000 - mean_absolute_error: 1228136.0000 - val_loss: 1657129926656.0000 - val_mean_absolute_error: 1240636.3750
# Epoch 2/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1627606351872.0000 - mean_absolute_error: 1225078.0000 - val_loss: 1634164670464.0000 - val_mean_absolute_error: 1232108.0000
# Epoch 3/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1566594564096.0000 - mean_absolute_error: 1202480.0000 - val_loss: 1516965330944.0000 - val_mean_absolute_error: 1188410.0000
# Epoch 4/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1364772126720.0000 - mean_absolute_error: 1124695.3750 - val_loss: 1212009283584.0000 - val_mean_absolute_error: 1066647.7500
# Epoch 5/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 967044694016.0000 - mean_absolute_error: 950129.4375 - val_loss: 729895337984.0000 - val_mean_absolute_error: 832053.3125
# Epoch 6/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 491168006144.0000 - mean_absolute_error: 670455.5000 - val_loss: 304157917184.0000 - val_mean_absolute_error: 518095.0938
# Epoch 7/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 190619992064.0000 - mean_absolute_error: 387377.6250 - val_loss: 124553781248.0000 - val_mean_absolute_error: 301148.6250
# Epoch 8/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 93605535744.0000 - mean_absolute_error: 255356.2188 - val_loss: 75416330240.0000 - val_mean_absolute_error: 226524.4844
# Epoch 9/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 64168456192.0000 - mean_absolute_error: 207179.8906 - val_loss: 55922085888.0000 - val_mean_absolute_error: 193031.4844
# Epoch 10/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 51110952960.0000 - mean_absolute_error: 182955.1406 - val_loss: 45986091008.0000 - val_mean_absolute_error: 173686.5781
# Epoch 11/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 44108206080.0000 - mean_absolute_error: 168625.6094 - val_loss: 40242790400.0000 - val_mean_absolute_error: 161651.6250
# Epoch 12/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 39608426496.0000 - mean_absolute_error: 158834.7656 - val_loss: 36302540800.0000 - val_mean_absolute_error: 153235.1250
# Epoch 13/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 36229824512.0000 - mean_absolute_error: 151269.4688 - val_loss: 33175052288.0000 - val_mean_absolute_error: 146158.5000
# Epoch 14/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 33390362624.0000 - mean_absolute_error: 145010.3906 - val_loss: 30560655360.0000 - val_mean_absolute_error: 139973.5312
# Epoch 15/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 30871201792.0000 - mean_absolute_error: 139083.4219 - val_loss: 28223309824.0000 - val_mean_absolute_error: 134250.0000
# Epoch 16/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 28648124416.0000 - mean_absolute_error: 133819.1094 - val_loss: 26181593088.0000 - val_mean_absolute_error: 128938.7969
# Epoch 17/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 26606438400.0000 - mean_absolute_error: 128670.3516 - val_loss: 24326987776.0000 - val_mean_absolute_error: 123992.3516
# Epoch 18/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 24774805504.0000 - mean_absolute_error: 124125.0781 - val_loss: 22622633984.0000 - val_mean_absolute_error: 119311.2891
# Epoch 19/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 23143127040.0000 - mean_absolute_error: 119604.6719 - val_loss: 21157437440.0000 - val_mean_absolute_error: 115163.9219
# Epoch 20/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 21689968640.0000 - mean_absolute_error: 115830.7656 - val_loss: 19871076352.0000 - val_mean_absolute_error: 111284.9062
# Epoch 21/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 20394420224.0000 - mean_absolute_error: 112155.1562 - val_loss: 18726176768.0000 - val_mean_absolute_error: 107758.9688
# Epoch 22/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 19235860480.0000 - mean_absolute_error: 109024.2578 - val_loss: 17714782208.0000 - val_mean_absolute_error: 104754.7500
# Epoch 23/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 18206689280.0000 - mean_absolute_error: 106002.1484 - val_loss: 16749925376.0000 - val_mean_absolute_error: 101576.7031
# Epoch 24/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 17284173824.0000 - mean_absolute_error: 103285.8750 - val_loss: 16007262208.0000 - val_mean_absolute_error: 99331.0312
# Epoch 25/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 16467130368.0000 - mean_absolute_error: 100931.9844 - val_loss: 15288923136.0000 - val_mean_absolute_error: 96985.4219
# Epoch 26/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 15750812672.0000 - mean_absolute_error: 98854.0859 - val_loss: 14680701952.0000 - val_mean_absolute_error: 95034.3281
# Epoch 27/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 15101273088.0000 - mean_absolute_error: 96920.4297 - val_loss: 14100235264.0000 - val_mean_absolute_error: 93126.8125
# Epoch 28/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 14536084480.0000 - mean_absolute_error: 95139.7422 - val_loss: 13631577088.0000 - val_mean_absolute_error: 91615.1797
# Epoch 29/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 14050356224.0000 - mean_absolute_error: 93613.8594 - val_loss: 13214949376.0000 - val_mean_absolute_error: 90329.2500
# Epoch 30/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 13606967296.0000 - mean_absolute_error: 92310.0312 - val_loss: 12870405120.0000 - val_mean_absolute_error: 89277.7969
# Epoch 31/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 13236504576.0000 - mean_absolute_error: 91105.4609 - val_loss: 12544763904.0000 - val_mean_absolute_error: 88259.0547
# Epoch 32/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 12894181376.0000 - mean_absolute_error: 90107.9219 - val_loss: 12273363968.0000 - val_mean_absolute_error: 87353.0391
# Epoch 33/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 12622774272.0000 - mean_absolute_error: 89215.5312 - val_loss: 12044678144.0000 - val_mean_absolute_error: 86725.3047
# Epoch 34/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 12359858176.0000 - mean_absolute_error: 88345.5391 - val_loss: 11855104000.0000 - val_mean_absolute_error: 86080.8984
# Epoch 35/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 12151975936.0000 - mean_absolute_error: 87744.4141 - val_loss: 11677622272.0000 - val_mean_absolute_error: 85613.3828
# Epoch 36/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 11943920640.0000 - mean_absolute_error: 87047.2266 - val_loss: 11494969344.0000 - val_mean_absolute_error: 84973.7969
# Epoch 37/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 11791373312.0000 - mean_absolute_error: 86537.1484 - val_loss: 11407271936.0000 - val_mean_absolute_error: 84806.7812
# Epoch 38/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 11638450176.0000 - mean_absolute_error: 86018.6406 - val_loss: 11248271360.0000 - val_mean_absolute_error: 84302.8047
# Epoch 39/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 11495835648.0000 - mean_absolute_error: 85606.7812 - val_loss: 11167966208.0000 - val_mean_absolute_error: 84078.4297
# Epoch 40/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 11394762752.0000 - mean_absolute_error: 85224.5781 - val_loss: 11046180864.0000 - val_mean_absolute_error: 83659.3125
# Epoch 41/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 11309396992.0000 - mean_absolute_error: 84871.3672 - val_loss: 10957393920.0000 - val_mean_absolute_error: 83420.3750
# Epoch 42/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 11205561344.0000 - mean_absolute_error: 84612.2891 - val_loss: 10922229760.0000 - val_mean_absolute_error: 83373.1875
# Epoch 43/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 11102013440.0000 - mean_absolute_error: 84202.5312 - val_loss: 10841997312.0000 - val_mean_absolute_error: 83211.9219
# Epoch 44/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 11055496192.0000 - mean_absolute_error: 84052.7344 - val_loss: 10793415680.0000 - val_mean_absolute_error: 83044.1797
# Epoch 45/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10997249024.0000 - mean_absolute_error: 83896.0703 - val_loss: 10730262528.0000 - val_mean_absolute_error: 82895.2031
# Epoch 46/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10925058048.0000 - mean_absolute_error: 83620.7578 - val_loss: 10695724032.0000 - val_mean_absolute_error: 82769.1484
# Epoch 47/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10892855296.0000 - mean_absolute_error: 83562.8906 - val_loss: 10655580160.0000 - val_mean_absolute_error: 82614.7266
# Epoch 48/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10839971840.0000 - mean_absolute_error: 83336.1797 - val_loss: 10611107840.0000 - val_mean_absolute_error: 82563.8750
# Epoch 49/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10791611392.0000 - mean_absolute_error: 83207.1250 - val_loss: 10565149696.0000 - val_mean_absolute_error: 82388.8047
# Epoch 50/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10759595008.0000 - mean_absolute_error: 83062.7500 - val_loss: 10550948864.0000 - val_mean_absolute_error: 82368.6797
# Epoch 51/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10718465024.0000 - mean_absolute_error: 82988.4609 - val_loss: 10527137792.0000 - val_mean_absolute_error: 82305.8906
# Epoch 52/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10726480896.0000 - mean_absolute_error: 83034.7500 - val_loss: 10566791168.0000 - val_mean_absolute_error: 82471.7422
# Epoch 53/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10644317184.0000 - mean_absolute_error: 82750.3281 - val_loss: 10524210176.0000 - val_mean_absolute_error: 82406.7969
# Epoch 54/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10651224064.0000 - mean_absolute_error: 82843.2109 - val_loss: 10578380800.0000 - val_mean_absolute_error: 82622.8203
# Epoch 55/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10633125888.0000 - mean_absolute_error: 82660.2578 - val_loss: 10429279232.0000 - val_mean_absolute_error: 82039.0547
# Epoch 56/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10612508672.0000 - mean_absolute_error: 82714.7188 - val_loss: 10425239552.0000 - val_mean_absolute_error: 82070.5312
# Epoch 57/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10582732800.0000 - mean_absolute_error: 82538.5156 - val_loss: 10414744576.0000 - val_mean_absolute_error: 82039.3047
# Epoch 58/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10608223232.0000 - mean_absolute_error: 82671.7812 - val_loss: 10382478336.0000 - val_mean_absolute_error: 81916.2422
# Epoch 59/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10547260416.0000 - mean_absolute_error: 82444.4219 - val_loss: 10391853056.0000 - val_mean_absolute_error: 81984.5938
# Epoch 60/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10546329600.0000 - mean_absolute_error: 82364.4609 - val_loss: 10459046912.0000 - val_mean_absolute_error: 82245.6562
# Epoch 61/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10519375872.0000 - mean_absolute_error: 82368.7891 - val_loss: 10370221056.0000 - val_mean_absolute_error: 81915.9062
# Epoch 62/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10507214848.0000 - mean_absolute_error: 82275.1875 - val_loss: 10351734784.0000 - val_mean_absolute_error: 81879.3594
# Epoch 63/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10497595392.0000 - mean_absolute_error: 82244.8359 - val_loss: 10333928448.0000 - val_mean_absolute_error: 81798.4141
# Epoch 64/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10479909888.0000 - mean_absolute_error: 82203.2188 - val_loss: 10338244608.0000 - val_mean_absolute_error: 81838.7734
# Epoch 65/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10497330176.0000 - mean_absolute_error: 82365.7969 - val_loss: 10324536320.0000 - val_mean_absolute_error: 81839.1406
# Epoch 66/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10474720256.0000 - mean_absolute_error: 82170.0625 - val_loss: 10333357056.0000 - val_mean_absolute_error: 81815.6797
# Epoch 67/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10476247040.0000 - mean_absolute_error: 82231.9922 - val_loss: 10293798912.0000 - val_mean_absolute_error: 81691.6875
# Epoch 68/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10451084288.0000 - mean_absolute_error: 82023.4688 - val_loss: 10302848000.0000 - val_mean_absolute_error: 81742.1094
# Epoch 69/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10451197952.0000 - mean_absolute_error: 82156.3359 - val_loss: 10299900928.0000 - val_mean_absolute_error: 81716.6719
# Epoch 70/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10432934912.0000 - mean_absolute_error: 82041.8594 - val_loss: 10287868928.0000 - val_mean_absolute_error: 81694.0391
# Epoch 71/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 10443864064.0000 - mean_absolute_error: 81998.1250 - val_loss: 10278488064.0000 - val_mean_absolute_error: 81637.5625
# Epoch 72/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10459233280.0000 - mean_absolute_error: 82174.6484 - val_loss: 10428833792.0000 - val_mean_absolute_error: 82168.4219
# Epoch 73/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10443204608.0000 - mean_absolute_error: 82135.5391 - val_loss: 10260185088.0000 - val_mean_absolute_error: 81581.8984
# Epoch 74/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10411129856.0000 - mean_absolute_error: 81992.4141 - val_loss: 10297254912.0000 - val_mean_absolute_error: 81731.3594
# Epoch 75/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10450466816.0000 - mean_absolute_error: 82132.6172 - val_loss: 10301324288.0000 - val_mean_absolute_error: 81818.9375
# Epoch 76/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10417434624.0000 - mean_absolute_error: 82019.5469 - val_loss: 10262799360.0000 - val_mean_absolute_error: 81617.3672
# Epoch 77/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 10389079040.0000 - mean_absolute_error: 81814.6016 - val_loss: 10318748672.0000 - val_mean_absolute_error: 81925.4766
# Epoch 78/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10398572544.0000 - mean_absolute_error: 82015.6797 - val_loss: 10264244224.0000 - val_mean_absolute_error: 81696.3125
# Epoch 79/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10451745792.0000 - mean_absolute_error: 82089.1328 - val_loss: 10285662208.0000 - val_mean_absolute_error: 81704.7344
# Epoch 80/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10406060032.0000 - mean_absolute_error: 81997.3906 - val_loss: 10235843584.0000 - val_mean_absolute_error: 81546.8125
# Epoch 81/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 10397504512.0000 - mean_absolute_error: 81948.7812 - val_loss: 10283974656.0000 - val_mean_absolute_error: 81734.4922
# Epoch 82/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10405599232.0000 - mean_absolute_error: 82031.2031 - val_loss: 10260973568.0000 - val_mean_absolute_error: 81735.1406
# Epoch 83/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10395688960.0000 - mean_absolute_error: 81992.3438 - val_loss: 10259090432.0000 - val_mean_absolute_error: 81651.1641
# Epoch 84/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10384608256.0000 - mean_absolute_error: 81940.4219 - val_loss: 10260925440.0000 - val_mean_absolute_error: 81712.6953
# Epoch 85/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10368389120.0000 - mean_absolute_error: 81848.2812 - val_loss: 10232020992.0000 - val_mean_absolute_error: 81559.9531
# Epoch 86/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10374760448.0000 - mean_absolute_error: 81849.6328 - val_loss: 10248666112.0000 - val_mean_absolute_error: 81662.2969
# Epoch 87/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10411604992.0000 - mean_absolute_error: 81970.2500 - val_loss: 10231528448.0000 - val_mean_absolute_error: 81617.7344
# Epoch 88/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10361312256.0000 - mean_absolute_error: 81894.8516 - val_loss: 10232365056.0000 - val_mean_absolute_error: 81584.8047
# Epoch 89/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10380058624.0000 - mean_absolute_error: 81900.4609 - val_loss: 10314682368.0000 - val_mean_absolute_error: 81870.7812
# Epoch 90/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10379328512.0000 - mean_absolute_error: 81944.1094 - val_loss: 10244614144.0000 - val_mean_absolute_error: 81623.8906
# Epoch 91/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10355259392.0000 - mean_absolute_error: 81748.5469 - val_loss: 10227804160.0000 - val_mean_absolute_error: 81613.6719
# Epoch 92/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10344183808.0000 - mean_absolute_error: 81688.8281 - val_loss: 10235222016.0000 - val_mean_absolute_error: 81605.7734
# Epoch 93/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10347523072.0000 - mean_absolute_error: 81665.8047 - val_loss: 10231686144.0000 - val_mean_absolute_error: 81644.6719
# Epoch 94/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10339435520.0000 - mean_absolute_error: 81600.7734 - val_loss: 10253393920.0000 - val_mean_absolute_error: 81752.6641
# Epoch 95/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10361562112.0000 - mean_absolute_error: 81811.7109 - val_loss: 10223081472.0000 - val_mean_absolute_error: 81649.4062
# Epoch 96/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10331348992.0000 - mean_absolute_error: 81707.9297 - val_loss: 10226800640.0000 - val_mean_absolute_error: 81611.9766
# Epoch 97/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10337911808.0000 - mean_absolute_error: 81718.5000 - val_loss: 10215911424.0000 - val_mean_absolute_error: 81545.9453
# Epoch 98/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10335312896.0000 - mean_absolute_error: 81702.2188 - val_loss: 10222268416.0000 - val_mean_absolute_error: 81578.2734
# Epoch 99/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10363198464.0000 - mean_absolute_error: 81893.8047 - val_loss: 10230679552.0000 - val_mean_absolute_error: 81588.7109
# Epoch 100/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10343638016.0000 - mean_absolute_error: 81773.9922 - val_loss: 10212591616.0000 - val_mean_absolute_error: 81615.6172
# Epoch 101/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10364384256.0000 - mean_absolute_error: 81815.0234 - val_loss: 10198774784.0000 - val_mean_absolute_error: 81539.2578
# Epoch 102/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10323879936.0000 - mean_absolute_error: 81658.8359 - val_loss: 10203872256.0000 - val_mean_absolute_error: 81609.4062
# Epoch 103/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10328511488.0000 - mean_absolute_error: 81685.5469 - val_loss: 10208296960.0000 - val_mean_absolute_error: 81541.8984
# Epoch 104/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10328904704.0000 - mean_absolute_error: 81692.3516 - val_loss: 10211627008.0000 - val_mean_absolute_error: 81606.6328
# Epoch 105/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10352436224.0000 - mean_absolute_error: 81792.5156 - val_loss: 10204022784.0000 - val_mean_absolute_error: 81540.2422
# Epoch 106/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10335217664.0000 - mean_absolute_error: 81708.7109 - val_loss: 10205337600.0000 - val_mean_absolute_error: 81550.4219
# Epoch 107/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10332431360.0000 - mean_absolute_error: 81731.8984 - val_loss: 10228262912.0000 - val_mean_absolute_error: 81655.9766
# Epoch 108/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10339546112.0000 - mean_absolute_error: 81820.0469 - val_loss: 10219330560.0000 - val_mean_absolute_error: 81652.8750
# Epoch 109/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10331143168.0000 - mean_absolute_error: 81698.2109 - val_loss: 10233019392.0000 - val_mean_absolute_error: 81637.4844
# Epoch 110/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10308763648.0000 - mean_absolute_error: 81716.3594 - val_loss: 10211141632.0000 - val_mean_absolute_error: 81653.2344
# Epoch 111/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10335467520.0000 - mean_absolute_error: 81736.6484 - val_loss: 10374852608.0000 - val_mean_absolute_error: 82096.4922
# Epoch 112/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10339036160.0000 - mean_absolute_error: 81752.8125 - val_loss: 10192226304.0000 - val_mean_absolute_error: 81520.2812
# Epoch 113/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10307607552.0000 - mean_absolute_error: 81601.0859 - val_loss: 10219283456.0000 - val_mean_absolute_error: 81567.9766
# Epoch 114/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10326975488.0000 - mean_absolute_error: 81668.2188 - val_loss: 10212966400.0000 - val_mean_absolute_error: 81588.1172
# Epoch 115/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10310479872.0000 - mean_absolute_error: 81614.0781 - val_loss: 10184085504.0000 - val_mean_absolute_error: 81467.5469
# Epoch 116/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10321832960.0000 - mean_absolute_error: 81681.9453 - val_loss: 10188533760.0000 - val_mean_absolute_error: 81517.9219
# Epoch 117/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10308537344.0000 - mean_absolute_error: 81659.9141 - val_loss: 10228044800.0000 - val_mean_absolute_error: 81658.1797
# Epoch 118/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10308001792.0000 - mean_absolute_error: 81638.8281 - val_loss: 10196175872.0000 - val_mean_absolute_error: 81524.6328
# Epoch 119/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10301253632.0000 - mean_absolute_error: 81627.6328 - val_loss: 10285730816.0000 - val_mean_absolute_error: 81834.0312
# Epoch 120/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10306776064.0000 - mean_absolute_error: 81618.8906 - val_loss: 10205079552.0000 - val_mean_absolute_error: 81579.9922
# Epoch 121/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10300955648.0000 - mean_absolute_error: 81666.2969 - val_loss: 10225556480.0000 - val_mean_absolute_error: 81708.6172
# Epoch 122/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10336456704.0000 - mean_absolute_error: 81748.7734 - val_loss: 10236093440.0000 - val_mean_absolute_error: 81648.7891
# Epoch 123/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10333735936.0000 - mean_absolute_error: 81706.5234 - val_loss: 10211588096.0000 - val_mean_absolute_error: 81617.5469
# Epoch 124/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10296958976.0000 - mean_absolute_error: 81640.2266 - val_loss: 10232065024.0000 - val_mean_absolute_error: 81695.1016
# Epoch 125/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10348038144.0000 - mean_absolute_error: 81832.6641 - val_loss: 10207728640.0000 - val_mean_absolute_error: 81596.6094
# Epoch 126/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10305697792.0000 - mean_absolute_error: 81570.3438 - val_loss: 10191765504.0000 - val_mean_absolute_error: 81508.8984
# Epoch 127/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10296353792.0000 - mean_absolute_error: 81538.0234 - val_loss: 10262276096.0000 - val_mean_absolute_error: 81744.0625
# Epoch 128/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10299420672.0000 - mean_absolute_error: 81597.1875 - val_loss: 10179533824.0000 - val_mean_absolute_error: 81460.9844
# Epoch 129/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10302627840.0000 - mean_absolute_error: 81651.4766 - val_loss: 10219473920.0000 - val_mean_absolute_error: 81704.9766
# Epoch 130/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10308341760.0000 - mean_absolute_error: 81629.6016 - val_loss: 10200094720.0000 - val_mean_absolute_error: 81596.0234
# Epoch 131/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10306571264.0000 - mean_absolute_error: 81572.1719 - val_loss: 10278778880.0000 - val_mean_absolute_error: 81838.1562
# Epoch 132/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10316320768.0000 - mean_absolute_error: 81675.3750 - val_loss: 10186682368.0000 - val_mean_absolute_error: 81513.9922
# Epoch 133/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10290796544.0000 - mean_absolute_error: 81658.5234 - val_loss: 10216911872.0000 - val_mean_absolute_error: 81616.2109
# Epoch 134/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10300808192.0000 - mean_absolute_error: 81599.7734 - val_loss: 10261300224.0000 - val_mean_absolute_error: 81758.7734
# Epoch 135/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10317249536.0000 - mean_absolute_error: 81698.0391 - val_loss: 10173682688.0000 - val_mean_absolute_error: 81461.5312
# Epoch 136/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 10297100288.0000 - mean_absolute_error: 81517.3359 - val_loss: 10232633344.0000 - val_mean_absolute_error: 81735.7969
# Epoch 137/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10348155904.0000 - mean_absolute_error: 81819.3516 - val_loss: 10176555008.0000 - val_mean_absolute_error: 81511.0703
# Epoch 138/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10311646208.0000 - mean_absolute_error: 81661.7969 - val_loss: 10244103168.0000 - val_mean_absolute_error: 81696.7812
# Epoch 139/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10307342336.0000 - mean_absolute_error: 81688.1172 - val_loss: 10192130048.0000 - val_mean_absolute_error: 81552.1250
# Epoch 140/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10313171968.0000 - mean_absolute_error: 81644.1172 - val_loss: 10201985024.0000 - val_mean_absolute_error: 81578.8828
# Epoch 141/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10321606656.0000 - mean_absolute_error: 81753.7500 - val_loss: 10270697472.0000 - val_mean_absolute_error: 81783.2031
# Epoch 142/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10303640576.0000 - mean_absolute_error: 81594.6953 - val_loss: 10187284480.0000 - val_mean_absolute_error: 81533.1953
# Epoch 143/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10310393856.0000 - mean_absolute_error: 81630.6641 - val_loss: 10182929408.0000 - val_mean_absolute_error: 81518.8203
# Epoch 144/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10300627968.0000 - mean_absolute_error: 81663.3984 - val_loss: 10166764544.0000 - val_mean_absolute_error: 81462.9844
# Epoch 145/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10310561792.0000 - mean_absolute_error: 81671.2344 - val_loss: 10172276736.0000 - val_mean_absolute_error: 81514.2344
# Epoch 146/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10283636736.0000 - mean_absolute_error: 81579.5391 - val_loss: 10191992832.0000 - val_mean_absolute_error: 81499.1094
# Epoch 147/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10287499264.0000 - mean_absolute_error: 81489.1953 - val_loss: 10184478720.0000 - val_mean_absolute_error: 81520.3984
# Epoch 148/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10295538688.0000 - mean_absolute_error: 81550.5625 - val_loss: 10172528640.0000 - val_mean_absolute_error: 81472.2031
# Epoch 149/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10305637376.0000 - mean_absolute_error: 81777.4531 - val_loss: 10180440064.0000 - val_mean_absolute_error: 81529.8984
# Epoch 150/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10315940864.0000 - mean_absolute_error: 81708.4375 - val_loss: 10195280896.0000 - val_mean_absolute_error: 81613.8906
# Epoch 151/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10276684800.0000 - mean_absolute_error: 81637.3828 - val_loss: 10228047872.0000 - val_mean_absolute_error: 81647.0234
# Epoch 152/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10288971776.0000 - mean_absolute_error: 81595.6641 - val_loss: 10206913536.0000 - val_mean_absolute_error: 81580.5312
# Epoch 153/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10291177472.0000 - mean_absolute_error: 81602.4609 - val_loss: 10182075392.0000 - val_mean_absolute_error: 81563.1562
# Epoch 154/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10279072768.0000 - mean_absolute_error: 81525.6016 - val_loss: 10210756608.0000 - val_mean_absolute_error: 81643.4922
# Epoch 155/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10322680832.0000 - mean_absolute_error: 81590.7031 - val_loss: 10190630912.0000 - val_mean_absolute_error: 81535.2031
# Epoch 156/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10302691328.0000 - mean_absolute_error: 81628.7734 - val_loss: 10180507648.0000 - val_mean_absolute_error: 81545.1484
# Epoch 157/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10279857152.0000 - mean_absolute_error: 81587.9922 - val_loss: 10210909184.0000 - val_mean_absolute_error: 81697.4062
# Epoch 158/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10298866688.0000 - mean_absolute_error: 81527.6406 - val_loss: 10193894400.0000 - val_mean_absolute_error: 81590.2891
# Epoch 159/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10269159424.0000 - mean_absolute_error: 81531.2031 - val_loss: 10192763904.0000 - val_mean_absolute_error: 81550.3438
# Epoch 160/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10279857152.0000 - mean_absolute_error: 81517.9531 - val_loss: 10177567744.0000 - val_mean_absolute_error: 81523.4688
# Epoch 161/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10310629376.0000 - mean_absolute_error: 81741.4766 - val_loss: 10201482240.0000 - val_mean_absolute_error: 81563.2344
# Epoch 162/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10273061888.0000 - mean_absolute_error: 81442.4062 - val_loss: 10209344512.0000 - val_mean_absolute_error: 81572.0078
# Epoch 163/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10294212608.0000 - mean_absolute_error: 81518.5391 - val_loss: 10193999872.0000 - val_mean_absolute_error: 81579.3516
# Epoch 164/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10298777600.0000 - mean_absolute_error: 81544.9688 - val_loss: 10169425920.0000 - val_mean_absolute_error: 81450.6484
# Epoch 165/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10324603904.0000 - mean_absolute_error: 81751.5703 - val_loss: 10178152448.0000 - val_mean_absolute_error: 81542.7266
# Epoch 166/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10306941952.0000 - mean_absolute_error: 81681.0312 - val_loss: 10292136960.0000 - val_mean_absolute_error: 81842.0625
# Epoch 167/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10302517248.0000 - mean_absolute_error: 81770.1484 - val_loss: 10262984704.0000 - val_mean_absolute_error: 81768.1797
# Epoch 168/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10295136256.0000 - mean_absolute_error: 81601.5078 - val_loss: 10180975616.0000 - val_mean_absolute_error: 81466.6328
# Epoch 169/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10289058816.0000 - mean_absolute_error: 81577.3359 - val_loss: 10174235648.0000 - val_mean_absolute_error: 81487.9219
# Epoch 170/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10273945600.0000 - mean_absolute_error: 81472.2578 - val_loss: 10185749504.0000 - val_mean_absolute_error: 81517.9766
# Epoch 171/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10277219328.0000 - mean_absolute_error: 81541.6562 - val_loss: 10240611328.0000 - val_mean_absolute_error: 81704.3438
# Epoch 172/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10273447936.0000 - mean_absolute_error: 81495.1016 - val_loss: 10197852160.0000 - val_mean_absolute_error: 81585.0781
# Epoch 173/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 10283573248.0000 - mean_absolute_error: 81634.0547 - val_loss: 10212476928.0000 - val_mean_absolute_error: 81521.7031
# Epoch 174/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 10280788992.0000 - mean_absolute_error: 81493.7109 - val_loss: 10211941376.0000 - val_mean_absolute_error: 81608.3750
# Epoch 175/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 10276408320.0000 - mean_absolute_error: 81501.8750 - val_loss: 10174796800.0000 - val_mean_absolute_error: 81480.7656
# Epoch 176/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 10266535936.0000 - mean_absolute_error: 81513.3828 - val_loss: 10251593728.0000 - val_mean_absolute_error: 81746.3516
# Epoch 177/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 10286982144.0000 - mean_absolute_error: 81440.0156 - val_loss: 10246612992.0000 - val_mean_absolute_error: 81731.1484
# Epoch 178/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10286188544.0000 - mean_absolute_error: 81603.1875 - val_loss: 10174795776.0000 - val_mean_absolute_error: 81543.2422
# Epoch 179/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10274441216.0000 - mean_absolute_error: 81535.9531 - val_loss: 10165244928.0000 - val_mean_absolute_error: 81500.3594
# Epoch 180/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10270932992.0000 - mean_absolute_error: 81563.5859 - val_loss: 10197905408.0000 - val_mean_absolute_error: 81524.0234
# Epoch 181/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10269247488.0000 - mean_absolute_error: 81443.7656 - val_loss: 10182178816.0000 - val_mean_absolute_error: 81531.2422
# Epoch 182/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10300569600.0000 - mean_absolute_error: 81598.4531 - val_loss: 10188737536.0000 - val_mean_absolute_error: 81564.4844
# Epoch 183/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10273640448.0000 - mean_absolute_error: 81457.1797 - val_loss: 10196500480.0000 - val_mean_absolute_error: 81591.7422
# Epoch 184/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10275585024.0000 - mean_absolute_error: 81600.3906 - val_loss: 10178732032.0000 - val_mean_absolute_error: 81544.3281
# Epoch 185/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10288408576.0000 - mean_absolute_error: 81629.4922 - val_loss: 10210983936.0000 - val_mean_absolute_error: 81710.3594
# Epoch 186/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10302798848.0000 - mean_absolute_error: 81693.0000 - val_loss: 10198595584.0000 - val_mean_absolute_error: 81671.0312
# Epoch 187/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10279557120.0000 - mean_absolute_error: 81538.2969 - val_loss: 10200799232.0000 - val_mean_absolute_error: 81584.5859
# Epoch 188/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10263277568.0000 - mean_absolute_error: 81542.9688 - val_loss: 10220188672.0000 - val_mean_absolute_error: 81676.4297
# Epoch 189/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10274073600.0000 - mean_absolute_error: 81522.2031 - val_loss: 10251712512.0000 - val_mean_absolute_error: 81701.4375
# Epoch 190/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10289527808.0000 - mean_absolute_error: 81528.1562 - val_loss: 10179232768.0000 - val_mean_absolute_error: 81464.9219
# Epoch 191/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10272766976.0000 - mean_absolute_error: 81564.8672 - val_loss: 10240751616.0000 - val_mean_absolute_error: 81857.8594
# Epoch 192/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10266065920.0000 - mean_absolute_error: 81514.2109 - val_loss: 10187103232.0000 - val_mean_absolute_error: 81570.4531
# Epoch 193/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10313419776.0000 - mean_absolute_error: 81743.6406 - val_loss: 10216797184.0000 - val_mean_absolute_error: 81737.5078
# Epoch 194/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10310645760.0000 - mean_absolute_error: 81614.8125 - val_loss: 10181487616.0000 - val_mean_absolute_error: 81544.7188
# Epoch 195/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 10258985984.0000 - mean_absolute_error: 81457.3594 - val_loss: 10235273216.0000 - val_mean_absolute_error: 81704.1406
# Epoch 196/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10250679296.0000 - mean_absolute_error: 81468.8203 - val_loss: 10171869184.0000 - val_mean_absolute_error: 81562.1328
# Epoch 197/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10287353856.0000 - mean_absolute_error: 81546.8828 - val_loss: 10196179968.0000 - val_mean_absolute_error: 81507.7578
# Epoch 198/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10278716416.0000 - mean_absolute_error: 81510.4062 - val_loss: 10175425536.0000 - val_mean_absolute_error: 81541.9844
# Epoch 199/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10287480832.0000 - mean_absolute_error: 81602.2422 - val_loss: 10172085248.0000 - val_mean_absolute_error: 81551.5312
# Epoch 200/200
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10261749760.0000 - mean_absolute_error: 81462.7656 - val_loss: 10179246080.0000 - val_mean_absolute_error: 81566.5312

# %%
test_loss, test_mae = model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"Test MAE: {test_mae:.0f}")

predictions = model.predict(X_test_scaled).flatten()
r2 = r2_score(y_test, predictions)
print(f"R²: {r2:.4f}")
# Out:
# Test MAE: 81567
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# R²: 0.9137

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.scatter(y_test, predictions_lr, alpha=0.6, color='orange', label='Линейная регрессия', s=30)

plt.scatter(y_test, predictions, alpha=0.6, color='steelblue', label='Нейронная сеть', s=30)

plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Идеальная линия')

plt.xlabel('Истинная цена')
plt.ylabel('Предсказанная цена')
plt.title('Сравнение: Линейная регрессия; Нейронная сеть')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Бэггинг

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt

rf = RandomForestRegressor(
    n_estimators=100,
    max_depth=10,
    random_state=42
)

rf.fit(X_train, y_train)  
predictions_rf = rf.predict(X_test)

# %% [markdown]
# ## Сравнение моделей

# %%
mae_rf = mean_absolute_error(y_test, predictions_rf)
r2_rf = r2_score(y_test, predictions_rf)

models = ['Линейная', 'Нейронная', 'Random\nForest']
mae_values = [81135, test_mae, mae_rf]
r2_values = [0.9147, r2, r2_rf]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

colors = ['blue', 'green', 'red']
ax1.bar(models, mae_values, color=colors)
ax1.set_title('Средняя ошибка (MAE)')
ax1.set_ylabel('Ошибка ($)')
ax1.grid(True, alpha=0.3)

for i, v in enumerate(mae_values):
    ax1.text(i, v + 500, f'{v:,.0f}', ha='center')

ax2.bar(models, r2_values, color=colors)
ax2.set_title('Точность модели (R²)')
ax2.set_ylabel('Точность')
ax2.set_ylim(0.85, 0.92)
ax2.grid(True, alpha=0.3)

for i, v in enumerate(r2_values):
    ax2.text(i, v + 0.001, f'{v:.4f}', ha='center')

plt.suptitle('Сравнение моделей', fontsize=14)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.scatter(y_test, predictions_lr, alpha=0.6, color='orange', label='Линейная регрессия', s=30)
plt.scatter(y_test, predictions, alpha=0.6, color='steelblue', label='Нейронная сеть', s=30)
plt.scatter(y_test, predictions_rf, alpha=0.6, color='green', label='Random Forest', s=30)

plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2, label='Идеальная линия')

plt.xlabel('Истинная цена')
plt.ylabel('Предсказанная цена')
plt.title('Сравнение: Линейная регрессия; Нейронная сеть; Random Forest')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Анализ результатов:
#
# #### 1. **Линейная регрессия — лучшая модель**
# Линейная регрессия показала наилучшие результаты по обеим метрикам:
# - **Наименьшая ошибка MAE:** 81,135 (самая точная модель в абсолютных значениях)
# - **Наибольший R² Score:** 0.9147 (объясняет 91.47% дисперсии данных)
#
# #### 2. **Нейронная сеть — хорошая альтернатива**
# Нейронная сеть так же хорошо обучилась:
# - **MAE:** 81,567 (всего на 432 единицы хуже линейной регрессии)
# - **R² Score:** 0.9137 (разница всего 0.001)
# - Практически идентичная производительность с линейной регрессией
#
# #### 3. **Random Forest — наихудший результат**
# Random Forest показал значительно более низкие результаты:
# - **MAE:** 94,933 (на 13,798 больше, чем у линейной регрессии)
# - **R² Score:** 0.8776 (на 3.71% хуже объясняет дисперсию)
